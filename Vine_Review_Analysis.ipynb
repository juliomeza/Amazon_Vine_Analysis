# %%
import pandas as pd

# %%
# Import Vine Table
df = pd.read_csv('vine_table.csv')
df
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 0         RQ58W7SMO911M          4.0            2.0          3.0    N
# 1          RF6IUKMGL8SF          3.0            5.0          5.0    N
# 2        R1DOSHH6AI622S          4.0            1.0         22.0    N
# 3         RATOTLA3OF70O          5.0            2.0          2.0    N
# 4        R1TNWRKIVHVYOV          4.0            0.0          2.0    N
# ...                 ...          ...            ...          ...  ...
# 3105515  R1U2RAML67OKWM          4.0            9.0          9.0    N
# 3105516  R33HOJ2OWJIDQI          5.0           27.0         27.0    N
# 3105517   RPLV77JZXG575          4.0            4.0          4.0    N
# 3105518   RHL4UW17ZK72A          5.0            9.0          9.0    N
# 3105519  R34N4QWDXX58WB          4.0           12.0         13.0    N
#
#         verified_purchase
# 0                       N
# 1                       N
# 2                       N
# ...

# %%
# Number of Paid Reviews before all filterings
df.loc[df['vine'] == 'Y']
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 59102    R2NKNL4WXWIWBG          4.0            3.0          3.0    Y
# 1198651   RAIG9ZQDMBF5P          5.0            3.0          6.0    Y
#
#         verified_purchase
# 59102                   Y
# 1198651                 N

# %%
# Filter by total votes greater or equal than 20
total_votes_20 = df.loc[df['total_votes'] >= 20]
total_votes_20
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 2        R1DOSHH6AI622S          4.0            1.0         22.0    N
# 8        R1VE0FQQ0QTQJN          5.0           16.0         20.0    N
# 16       R1AABFZH0J0C0C          3.0           17.0         35.0    N
# 17       R3SJYLG07EHNE9          2.0           16.0         34.0    N
# 22       R3MD5TZJGIPTDU          5.0           21.0         31.0    N
# ...                 ...          ...            ...          ...  ...
# 3105453   R2OD2TECAR3RM          5.0           19.0         20.0    N
# 3105473  R117GB0UNIVGV9          5.0           33.0         33.0    N
# 3105479  R1DZ6KX3SWKFK2          5.0           45.0         47.0    N
# 3105507  R2YS7NYUYEWWN0          5.0           26.0         29.0    N
# 3105516  R33HOJ2OWJIDQI          5.0           27.0         27.0    N
#
#         verified_purchase
# 2                       N
# 8                       Y
# 16                      N
# ...

# %%
# Filter by (helpful votes / total votes) greater or equal than 0.5
helpful_total_votes = total_votes_20.loc[(total_votes_20['helpful_votes'] / total_votes_20['total_votes']) >= 0.5]
helpful_total_votes
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 8        R1VE0FQQ0QTQJN          5.0           16.0         20.0    N
# 22       R3MD5TZJGIPTDU          5.0           21.0         31.0    N
# 33        RX6OWUF8EFZ72          5.0           27.0         28.0    N
# 51       R1OPUF771LL5O5          4.0           27.0         27.0    N
# 59       R3AW5JRZYH66M5          1.0          268.0        307.0    N
# ...                 ...          ...            ...          ...  ...
# 3105453   R2OD2TECAR3RM          5.0           19.0         20.0    N
# 3105473  R117GB0UNIVGV9          5.0           33.0         33.0    N
# 3105479  R1DZ6KX3SWKFK2          5.0           45.0         47.0    N
# 3105507  R2YS7NYUYEWWN0          5.0           26.0         29.0    N
# 3105516  R33HOJ2OWJIDQI          5.0           27.0         27.0    N
#
#         verified_purchase
# 8                       Y
# 22                      N
# 33                      N
# ...

# %% [markdown]
# ### Paid Reviews

# %%
# Paid Review
vine_Y = helpful_total_votes.loc[helpful_total_votes['vine'] == 'Y']
vine_Y
# Out:
# Empty DataFrame
# Columns: [review_id, star_rating, helpful_votes, total_votes, vine, verified_purchase]
# Index: []

# %%
# Total Number of Reviews
vine_Y.shape[0]
# Out:
# 0

# %%
# Total Number of 5-star reviews
vine_Y.loc[vine_N['star_rating'] == 5.0].shape[0]
# Out:
# 0

# %%
# Percentage of 5-star reviews
vine_Y.loc[vine_N['star_rating'] == 5.0].shape[0] / vine_Y.shape[0] * 100
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /var/folders/hh/z4yqbdpx5qn610dkmlgjr85c0000gn/T/ipykernel_34904/4220824992.py in <module>
#       1 # Percentage of 5-star reviews
# ----> 2 vine_Y.loc[vine_N['star_rating'] == 5.0].shape[0] / vine_Y.shape[0] * 100
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ### Unpaid Reviews

# %%
# Unpaid Review
vine_N = helpful_total_votes.loc[helpful_total_votes['vine'] == 'N']
vine_N
# Out:
#               review_id  star_rating  helpful_votes  total_votes vine  \
# 8        R1VE0FQQ0QTQJN          5.0           16.0         20.0    N
# 22       R3MD5TZJGIPTDU          5.0           21.0         31.0    N
# 33        RX6OWUF8EFZ72          5.0           27.0         28.0    N
# 51       R1OPUF771LL5O5          4.0           27.0         27.0    N
# 59       R3AW5JRZYH66M5          1.0          268.0        307.0    N
# ...                 ...          ...            ...          ...  ...
# 3105453   R2OD2TECAR3RM          5.0           19.0         20.0    N
# 3105473  R117GB0UNIVGV9          5.0           33.0         33.0    N
# 3105479  R1DZ6KX3SWKFK2          5.0           45.0         47.0    N
# 3105507  R2YS7NYUYEWWN0          5.0           26.0         29.0    N
# 3105516  R33HOJ2OWJIDQI          5.0           27.0         27.0    N
#
#         verified_purchase
# 8                       Y
# 22                      N
# 33                      N
# ...

# %%
# Total Number of Reviews (Unpaid)
vine_N.shape[0]
# Out:
# 403807

# %%
# Total Number of 5-star reviews (Unpaid)
vine_N.loc[vine_N['star_rating'] == 5.0].shape[0]
# Out:
# 242889

# %%
# Percentage of 5-star reviews (Unpaid)
vine_N.loc[vine_N['star_rating'] == 5.0].shape[0] / vine_N.shape[0] * 100
# Out:
# 60.14977452099642
